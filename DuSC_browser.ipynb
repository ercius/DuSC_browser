# %%
from pathlib import Path
import dusc_browser

dir_path = Path('/global/cfs/cdirs/ncemhub/distiller/counted/2025.06.13/')
app = dusc_browser.DuSC_app(path=dir_path)
await app._ui.ready
print('Hold shift to zoom with mouse wheel')
app._ui
