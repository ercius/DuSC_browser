# %% [markdown]
# # DuSC_browser in JupyterLab

# %%
from pathlib import Path
import dusc_browser

dir_path = Path('/global/cfs/cdirs/ncemhub/distiller/counted/2025.08.29/')
assert dir_path.exists(), f'Directory does not exist: {dir_path}'
app = dusc_browser.DuSC_app(path=dir_path)
await app._ui.ready
app._ui
